# %%
import numpy
import pandas as pd
import warnings 

data= 'vine_table'
warnings.filterwarnings('ignore')

# %%
vine_df = pd.read_csv(data, index_col= False)
vine_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0         RTIS3L2M1F5SM            5              0            0    N
# 1         R1ZV7R40OLHKD            5              0            0    N
# 2        R3BH071QLH8QMC            1              0            1    N
# 3        R127K9NTSXA2YH            3              0            0    N
# 4        R32ZWUXDJPW27Q            4              0            0    N
# ...                 ...          ...            ...          ...  ...
# 1785992   RPC430LWZJ60T            5              1            1    N
# 1785993  R347MZT5FH6HRJ            5              2            2    N
# 1785994   RJ5BETZP0VIUS            1              0            2    N
# 1785995   R85QTDO2KZMGO            1              1            3    N
# 1785996  R2W36RZZZNTYWF            5              1            1    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# ...

# %%
#filter total votes >= 20
filtered_df = vine_df[vine_df["total_votes"]>=20]
filtered_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 289      R3EZ0EPYLDA34S            1             14           31    N
# 483      R2FJ94555FZH32            2             55           60    N
# ...                 ...          ...            ...          ...  ...
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785714  R26KS4Q9G04FIV            2              8           21    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase
# 55                      N
# 74                      Y
# 209                     Y
# ...

# %%
#Filter the new DataFrame or table created in Step 1 and create a new DataFrame or 
#table to retrieve all the rows where the number of helpful_votes divided by 
#total_votes is equal to or greater than 50%.

filtered_df["votes_ratio"] = filtered_df.helpful_votes/ filtered_df.total_votes >= .5
filtered_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 289      R3EZ0EPYLDA34S            1             14           31    N
# 483      R2FJ94555FZH32            2             55           60    N
# ...                 ...          ...            ...          ...  ...
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785714  R26KS4Q9G04FIV            2              8           21    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase  ratio  votes_ratio
# 55                      N   True         True
# ...

# %%
vine_verified = filtered_df[filtered_df['verified_purchase']== 'Y']
vine_verified
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 74       R2CI0Y288CC7E2            1             21           35    N
# 209      R127WEQY2FM1T3            1            147          175    N
# 289      R3EZ0EPYLDA34S            1             14           31    N
# 537      R1U3AR67RE273L            1             51           65    N
# 1359      R6KTC1OPIOIIG            2             19           34    N
# ...                 ...          ...            ...          ...  ...
# 1784317  R3NEKOTM4JLXSA            3             19           21    N
# 1785029  R16IS0J74O0LCP            5             25           29    N
# 1785080  R2GY46U6ENI6DN            5             53           57    N
# 1785222  R217MVS435SRAB            5             51           51    N
# 1785344  R1PE5AJJ6GKILJ            5             22           50    N
#
#         verified_purchase  ratio  votes_ratio
# 74                      Y   True         True
# ...

# %%
vine_unverified = filtered_df[filtered_df['verified_purchase'] == "N"]
vine_unverified
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 55        R4PKAZRQJJX14            1             21           34    N
# 483      R2FJ94555FZH32            2             55           60    N
# 670      R3PZOXA5X1U8KW            4             31           36    N
# 1402     R36O341WWXXKNP            5             28           31    N
# 1450     R3GSK9MM8DNOYI            1              4           32    N
# ...                 ...          ...            ...          ...  ...
# 1785688  R3GYUWLD9FWCPS            5             30           30    N
# 1785714  R26KS4Q9G04FIV            2              8           21    N
# 1785788   RU0J1ZMBCLD27            5             27           29    N
# 1785806  R1D69XH2THYKTG            5             18           20    N
# 1785935  R3U5C85OV6BUKM            4             38           43    N
#
#         verified_purchase  ratio  votes_ratio
# 55                      N   True         True
# ...

# %%
# Determine the total number of reviews, the number of 5-star reviews,
# and the percentage of 5-star reviews for the two types of review

verified_total_reviews = len(vine_verified)
unverified_total_reviews = len(vine_unverified)

verified_five_stars = (vine_verified['star_rating'].values ==5).sum()
unverified_five_stars = (vine_unverified['star_rating'].values ==5).sum()

verified_five_stars_percent = (verified_five_stars/verified_total_reviews)
unverified_five_stars_percent = (unverified_five_stars/unverified_total_reviews)

# %%
print(verified_total_reviews, verified_five_stars, verified_five_stars_percent)
print(unverified_total_reviews, unverified_five_stars, unverified_five_stars_percent)
# Out:
# 15742 4704 0.2988184474653792
# 49637 15783 0.3179684509539255
